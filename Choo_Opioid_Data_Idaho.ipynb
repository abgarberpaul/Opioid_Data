# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sn
import pprint


from scipy import stats

# %%
df = pd.read_csv('Resources/arcos-id-statewide-itemized.csv')  
df.head()
# Out:
# C:\Users\schoo2\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (3,22,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   REPORTER_DEA_NO REPORTER_BUS_ACT               REPORTER_NAME  \
# 0       PB0167127      DISTRIBUTOR  BLOODWORTH WHOLESALE DRUGS
# 1       PB0167127      DISTRIBUTOR  BLOODWORTH WHOLESALE DRUGS
# 2       PB0167127      DISTRIBUTOR  BLOODWORTH WHOLESALE DRUGS
# 3       PB0167127      DISTRIBUTOR  BLOODWORTH WHOLESALE DRUGS
# 4       PB0167127      DISTRIBUTOR  BLOODWORTH WHOLESALE DRUGS
#
#   REPORTER_ADDL_CO_INFO     REPORTER_ADDRESS1 REPORTER_ADDRESS2 REPORTER_CITY  \
# 0                   NaN  2128 YANK LAMB DRIVE     P.O. BOX 1849        TIFTON
# 1                   NaN  2128 YANK LAMB DRIVE     P.O. BOX 1849        TIFTON
# 2                   NaN  2128 YANK LAMB DRIVE     P.O. BOX 1849        TIFTON
# ...

# %%
df["Ingredient_Name"].unique()
# Out:
# array(['HYDROCODONE BITARTRATE HEMIPENTAHYDRATE',
#        'OXYCODONE HYDROCHLORIDE'], dtype=object)

# %%
df.count()
# Out:
# REPORTER_DEA_NO          1283838
# REPORTER_BUS_ACT         1283838
# REPORTER_NAME            1283838
# REPORTER_ADDL_CO_INFO      13642
# REPORTER_ADDRESS1        1283838
# REPORTER_ADDRESS2         670170
# REPORTER_CITY            1283838
# REPORTER_STATE           1283838
# REPORTER_ZIP             1283838
# REPORTER_COUNTY          1283838
# BUYER_DEA_NO             1283838
# BUYER_BUS_ACT            1283838
# BUYER_NAME               1283838
# BUYER_ADDL_CO_INFO        413823
# BUYER_ADDRESS1           1283838
# BUYER_ADDRESS2            274515
# BUYER_CITY               1283838
# BUYER_STATE              1283838
# BUYER_ZIP                1283838
# BUYER_COUNTY             1283838
# TRANSACTION_CODE         1283838
# DRUG_CODE                1283838
# NDC_NO                   1283838
# DRUG_NAME                1283838
# QUANTITY                 1283838
# UNIT                           0
# ACTION_INDICATOR            2093
# ORDER_FORM_NO             483946
# ...

# %%
df['BUYER_DEA_NO'].nunique()
# Out:
# 829

# %%
df_a = df[["REPORTER_NAME","MME"]]
df_a
# Out:
#                        REPORTER_NAME      MME
# 0         BLOODWORTH WHOLESALE DRUGS  18162.0
# 1         BLOODWORTH WHOLESALE DRUGS   4540.5
# 2         BLOODWORTH WHOLESALE DRUGS   6054.0
# 3         BLOODWORTH WHOLESALE DRUGS   3027.0
# 4         BLOODWORTH WHOLESALE DRUGS   9081.0
# ...                              ...      ...
# 1283833  MASTERS PHARMACEUTICAL, INC   1513.5
# 1283834  MASTERS PHARMACEUTICAL, INC   6054.0
# 1283835  MASTERS PHARMACEUTICAL, INC   3027.0
# 1283836  MASTERS PHARMACEUTICAL, INC   3027.0
# 1283837  MASTERS PHARMACEUTICAL, INC   4540.5
#
# [1283838 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['REPORTER_DEA_NO', 'REPORTER_BUS_ACT', 'REPORTER_NAME',
#        'REPORTER_ADDL_CO_INFO', 'REPORTER_ADDRESS1', 'REPORTER_ADDRESS2',
#        'REPORTER_CITY', 'REPORTER_STATE', 'REPORTER_ZIP', 'REPORTER_COUNTY',
#        'BUYER_DEA_NO', 'BUYER_BUS_ACT', 'BUYER_NAME', 'BUYER_ADDL_CO_INFO',
#        'BUYER_ADDRESS1', 'BUYER_ADDRESS2', 'BUYER_CITY', 'BUYER_STATE',
#        'BUYER_ZIP', 'BUYER_COUNTY', 'TRANSACTION_CODE', 'DRUG_CODE', 'NDC_NO',
#        'DRUG_NAME', 'QUANTITY', 'UNIT', 'ACTION_INDICATOR', 'ORDER_FORM_NO',
#        'CORRECTION_NO', 'STRENGTH', 'TRANSACTION_DATE', 'CALC_BASE_WT_IN_GM',
#        'DOSAGE_UNIT', 'TRANSACTION_ID', 'Product_Name', 'Ingredient_Name',
#        'Measure', 'MME_Conversion_Factor', 'Combined_Labeler_Name',
#        'Reporter_family', 'dos_str', 'MME'],
#       dtype='object')

# %%
df_group = df.groupby(["REPORTER_NAME"])

df_group.sum()
# Out:
#                                           REPORTER_ZIP    BUYER_ZIP  \
# REPORTER_NAME
# A-S MEDICATION SOLUTIONS LLC                  11409120     15904327
# ADVANTAGE LOGISTICS                         3031511420   4132345251
# AIDAREX PHARMACEUTICALS LLC                   13096080     11759964
# AL PHARMA                                       171660      1002016
# ALBERTSONS LLC DISTRIBUTION CENTER #8720    1320736104   1480470655
# ...                                                ...          ...
# WAL-MART WAREHOUSE #32                     12097338340  10843378834
# WALGREEN ARIZONA DRUG CO                     943635888    914230137
# WALGREEN CO                                11305556631   9883669631
# WEBSTER VETERINARY SUPPLY INC                   392128       334208
# WESTERN MEDICAL SUPPLY                          819054       754776
#
#                                            DRUG_CODE  QUANTITY  UNIT  \
# REPORTER_NAME
# ...

# %%
idaho_df = df[["REPORTER_DEA_NO","REPORTER_BUS_ACT", "REPORTER_NAME", "BUYER_DEA_NO", "BUYER_BUS_ACT", "BUYER_NAME","BUYER_COUNTY", "DRUG_NAME", "TRANSACTION_ID", "Product_Name" , "MME"]]
idaho_df.head()
# Out:
#   REPORTER_DEA_NO REPORTER_BUS_ACT               REPORTER_NAME BUYER_DEA_NO  \
# 0       PB0167127      DISTRIBUTOR  BLOODWORTH WHOLESALE DRUGS    BT5436224
# 1       PB0167127      DISTRIBUTOR  BLOODWORTH WHOLESALE DRUGS    BT5436224
# 2       PB0167127      DISTRIBUTOR  BLOODWORTH WHOLESALE DRUGS    BT5436224
# 3       PB0167127      DISTRIBUTOR  BLOODWORTH WHOLESALE DRUGS    BT5436224
# 4       PB0167127      DISTRIBUTOR  BLOODWORTH WHOLESALE DRUGS    BT5436224
#
#      BUYER_BUS_ACT     BUYER_NAME BUYER_COUNTY    DRUG_NAME  TRANSACTION_ID  \
# 0  RETAIL PHARMACY  KJ'S PHARMACY   TWIN FALLS  HYDROCODONE              87
# 1  RETAIL PHARMACY  KJ'S PHARMACY   TWIN FALLS  HYDROCODONE             770
# 2  RETAIL PHARMACY  KJ'S PHARMACY   TWIN FALLS  HYDROCODONE             240
# 3  RETAIL PHARMACY  KJ'S PHARMACY   TWIN FALLS  HYDROCODONE            3741
# 4  RETAIL PHARMACY  KJ'S PHARMACY   TWIN FALLS  HYDROCODONE            5806
#
#                            Product_Name      MME
# ...

# %%
ada_idaho_df = idaho_df[idaho_df["BUYER_COUNTY"] == 'ADA']

ada_idaho_df
# Out:
#         REPORTER_DEA_NO REPORTER_BUS_ACT  \
# 1826          PM0023046      DISTRIBUTOR
# 1827          PM0023046      DISTRIBUTOR
# 1828          PM0023046      DISTRIBUTOR
# 1829          PM0023046      DISTRIBUTOR
# 1830          PM0023046      DISTRIBUTOR
# ...                 ...              ...
# 1283820       RD0269109     MANUFACTURER
# 1283822       RD0271130      DISTRIBUTOR
# 1283824       RD0274364     MANUFACTURER
# 1283825       RD0274364     MANUFACTURER
# 1283837       RD0277409      DISTRIBUTOR
#
#                                 REPORTER_NAME BUYER_DEA_NO    BUYER_BUS_ACT  \
# 1826                     MCKESSON CORPORATION    AA1431218   CHAIN PHARMACY
# 1827                     MCKESSON CORPORATION    AA1431218   CHAIN PHARMACY
# 1828                     MCKESSON CORPORATION    AA1431218   CHAIN PHARMACY
# 1829                     MCKESSON CORPORATION    AA1431218   CHAIN PHARMACY
# 1830                     MCKESSON CORPORATION    AA1431218   CHAIN PHARMACY
# ...

# %%
ada_idaho_df.count()
# Out:
# REPORTER_DEA_NO     290524
# REPORTER_BUS_ACT    290524
# REPORTER_NAME       290524
# BUYER_DEA_NO        290524
# BUYER_BUS_ACT       290524
# BUYER_NAME          290524
# BUYER_COUNTY        290524
# DRUG_NAME           290524
# TRANSACTION_ID      290524
# Product_Name        290524
# MME                 290524
# dtype: int64

# %%
ada_idaho_df.to_csv(r'CSV_files/idaho_data.csv', index=False)

# %%
ada_idaho_df["BUYER_COUNTY"].value_counts()
# Out:
# ADA    290524
# Name: BUYER_COUNTY, dtype: int64

# %%
idaho_df["TRANSACTION_ID"].value_counts()
# Out:
# 5            66
# 6            63
# 3            60
# 1            60
# 8            59
#              ..
# 906006674     1
# 912006419     1
# 904020531     1
# 610012433     1
# 608013516     1
# Name: TRANSACTION_ID, Length: 872263, dtype: int64
