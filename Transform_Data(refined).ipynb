# %%
import pandas as pd
import pprint
from scipy import stats

# %%
# Import csv file for Oregon
file = "Resources/arcos-or-statewide-itemized.csv"
or_df = pd.read_csv(file)
or_df.head()
# Out:
# C:\Users\15038\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (3,5,22,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   REPORTER_DEA_NO REPORTER_BUS_ACT     REPORTER_NAME REPORTER_ADDL_CO_INFO  \
# 0       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 1       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 2       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 3       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 4       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
#
#         REPORTER_ADDRESS1 REPORTER_ADDRESS2     REPORTER_CITY REPORTER_STATE  \
# 0  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# 1  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# ...

# %%
# Import csv file for Washington 
wa_file = "Resources/arcos-wa-statewide-itemized.csv"
wa_df = pd.read_csv(wa_file)
wa_df.head()
# Out:
# C:\Users\15038\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (3,5,22,26,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   REPORTER_DEA_NO REPORTER_BUS_ACT     REPORTER_NAME REPORTER_ADDL_CO_INFO  \
# 0       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 1       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 2       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 3       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 4       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
#
#         REPORTER_ADDRESS1 REPORTER_ADDRESS2     REPORTER_CITY REPORTER_STATE  \
# 0  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# 1  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# ...

# %%
# Print column headers for cleaner look of what we're dealing with:
or_df.columns
# Out:
# Index(['REPORTER_DEA_NO', 'REPORTER_BUS_ACT', 'REPORTER_NAME',
#        'REPORTER_ADDL_CO_INFO', 'REPORTER_ADDRESS1', 'REPORTER_ADDRESS2',
#        'REPORTER_CITY', 'REPORTER_STATE', 'REPORTER_ZIP', 'REPORTER_COUNTY',
#        'BUYER_DEA_NO', 'BUYER_BUS_ACT', 'BUYER_NAME', 'BUYER_ADDL_CO_INFO',
#        'BUYER_ADDRESS1', 'BUYER_ADDRESS2', 'BUYER_CITY', 'BUYER_STATE',
#        'BUYER_ZIP', 'BUYER_COUNTY', 'TRANSACTION_CODE', 'DRUG_CODE', 'NDC_NO',
#        'DRUG_NAME', 'QUANTITY', 'UNIT', 'ACTION_INDICATOR', 'ORDER_FORM_NO',
#        'CORRECTION_NO', 'STRENGTH', 'TRANSACTION_DATE', 'CALC_BASE_WT_IN_GM',
#        'DOSAGE_UNIT', 'TRANSACTION_ID', 'Product_Name', 'Ingredient_Name',
#        'Measure', 'MME_Conversion_Factor', 'Combined_Labeler_Name',
#        'Reporter_family', 'dos_str', 'MME'],
#       dtype='object')

# %%
# Which rows are missing data in Oregon?
or_df.count()
# Out:
# REPORTER_DEA_NO          3492615
# REPORTER_BUS_ACT         3492615
# REPORTER_NAME            3492615
# REPORTER_ADDL_CO_INFO      27733
# REPORTER_ADDRESS1        3492615
# REPORTER_ADDRESS2        2087681
# REPORTER_CITY            3492615
# REPORTER_STATE           3492615
# REPORTER_ZIP             3492615
# REPORTER_COUNTY          3492615
# BUYER_DEA_NO             3492615
# BUYER_BUS_ACT            3492615
# BUYER_NAME               3492615
# BUYER_ADDL_CO_INFO       1777698
# BUYER_ADDRESS1           3492615
# BUYER_ADDRESS2            927778
# BUYER_CITY               3492615
# BUYER_STATE              3492615
# BUYER_ZIP                3492615
# BUYER_COUNTY             3492615
# TRANSACTION_CODE         3492615
# DRUG_CODE                3492615
# NDC_NO                   3492615
# DRUG_NAME                3492615
# QUANTITY                 3492615
# UNIT                           0
# ACTION_INDICATOR            7196
# ORDER_FORM_NO            1615188
# ...

# %%
# Which rows are missing data in Washington?
wa_df.count()
# Out:
# REPORTER_DEA_NO          5423267
# REPORTER_BUS_ACT         5423267
# REPORTER_NAME            5423267
# REPORTER_ADDL_CO_INFO      37032
# REPORTER_ADDRESS1        5423267
# REPORTER_ADDRESS2        3278517
# REPORTER_CITY            5423267
# REPORTER_STATE           5423267
# REPORTER_ZIP             5423267
# REPORTER_COUNTY          5423267
# BUYER_DEA_NO             5423267
# BUYER_BUS_ACT            5423267
# BUYER_NAME               5423267
# BUYER_ADDL_CO_INFO       2620902
# BUYER_ADDRESS1           5423267
# BUYER_ADDRESS2           1392960
# BUYER_CITY               5423267
# BUYER_STATE              5423267
# BUYER_ZIP                5423267
# BUYER_COUNTY             5423267
# TRANSACTION_CODE         5423267
# DRUG_CODE                5423267
# NDC_NO                   5423267
# DRUG_NAME                5423267
# QUANTITY                 5423267
# UNIT                           0
# ACTION_INDICATOR           10772
# ORDER_FORM_NO            2701246
# ...

# %%
# Create dataframe with only the columns that we want
oregon_data_df = or_df[["REPORTER_DEA_NO","REPORTER_BUS_ACT", "REPORTER_NAME", "BUYER_DEA_NO", "BUYER_BUS_ACT", "BUYER_NAME","BUYER_COUNTY", "DRUG_NAME", "TRANSACTION_ID", "Product_Name" , "MME"]]
oregon_data_df.head()
# Out:
#   REPORTER_DEA_NO REPORTER_BUS_ACT     REPORTER_NAME BUYER_DEA_NO  \
# 0       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP    BB8388010
# 1       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP    BB9517559
# 2       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP    BC8673279
# 3       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP    BG8412847
# 4       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP    BG8412847
#
#      BUYER_BUS_ACT                     BUYER_NAME BUYER_COUNTY    DRUG_NAME  \
# 0   CHAIN PHARMACY            BI-MART LA PINE 671    DESCHUTES    OXYCODONE
# 1  RETAIL PHARMACY                BHS EUGENE INC.         LANE  HYDROCODONE
# 2  RETAIL PHARMACY     CONSONUS PHARMACY SERVICES    CLACKAMAS  HYDROCODONE
# 3  RETAIL PHARMACY  GRESHAM PROFESSIONAL PHARMACY    MULTNOMAH  HYDROCODONE
# 4  RETAIL PHARMACY  GRESHAM PROFESSIONAL PHARMACY    MULTNOMAH  HYDROCODONE
#
#    TRANSACTION_ID                          Product_Name       MME
# ...

# %%
# CHECK COLUMN LENGTH, NO MISSING DATA
oregon_data_df.count()
# Out:
# REPORTER_DEA_NO     3492615
# REPORTER_BUS_ACT    3492615
# REPORTER_NAME       3492615
# BUYER_DEA_NO        3492615
# BUYER_BUS_ACT       3492615
# BUYER_NAME          3492615
# BUYER_COUNTY        3492615
# DRUG_NAME           3492615
# TRANSACTION_ID      3492615
# Product_Name        3492615
# MME                 3492615
# dtype: int64

# %%
# File too large for pgadmin. Slim down data, reduce Oregon data down to multnomah county.
OR_county_df = oregon_data_df.loc[oregon_data_df["BUYER_COUNTY"]=="MULTNOMAH"]
OR_county_df
# Out:
#         REPORTER_DEA_NO REPORTER_BUS_ACT                REPORTER_NAME  \
# 3             PB0034861      DISTRIBUTOR             BELLCO DRUG CORP
# 4             PB0034861      DISTRIBUTOR             BELLCO DRUG CORP
# 20            PH0234928     MANUFACTURER      H J HARKINS COMPANY INC
# 30            PK0132821      DISTRIBUTOR  KAISER FNDTN HEALTH PLAN NW
# 31            PK0132821      DISTRIBUTOR  KAISER FNDTN HEALTH PLAN NW
# ...                 ...              ...                          ...
# 3492581       RD0274364     MANUFACTURER         DISPENSING SOLUTIONS
# 3492592       RD0277409      DISTRIBUTOR  MASTERS PHARMACEUTICAL, INC
# 3492593       RD0277409      DISTRIBUTOR  MASTERS PHARMACEUTICAL, INC
# 3492594       RD0277409      DISTRIBUTOR  MASTERS PHARMACEUTICAL, INC
# 3492595       RD0277409      DISTRIBUTOR  MASTERS PHARMACEUTICAL, INC
#
#         BUYER_DEA_NO    BUYER_BUS_ACT                     BUYER_NAME  \
# ...

# %%
# Create dataframe with only the columns that we want
washington_data_df = wa_df[["REPORTER_DEA_NO","REPORTER_BUS_ACT", "REPORTER_NAME", "BUYER_DEA_NO", "BUYER_BUS_ACT", "BUYER_NAME","BUYER_COUNTY", "DRUG_NAME", "TRANSACTION_ID", "Product_Name" , "MME"]]
washington_data_df.head()
# Out:
#   REPORTER_DEA_NO REPORTER_BUS_ACT     REPORTER_NAME BUYER_DEA_NO  \
# 0       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP    AC8948056
# 1       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP    AC8948056
# 2       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP    AN8909888
# 3       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP    BB7776149
# 4       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP    BB7776149
#
#      BUYER_BUS_ACT                   BUYER_NAME BUYER_COUNTY    DRUG_NAME  \
# 0  RETAIL PHARMACY        CHINOOK PHARMACY, INC      CLALLAM  HYDROCODONE
# 1  RETAIL PHARMACY        CHINOOK PHARMACY, INC      CLALLAM  HYDROCODONE
# 2  RETAIL PHARMACY  NICHOLSON'S SUMNER PHARMACY       PIERCE    OXYCODONE
# 3  RETAIL PHARMACY   BATES PHARMACY AND MEDICAL      SPOKANE  HYDROCODONE
# 4  RETAIL PHARMACY   BATES PHARMACY AND MEDICAL      SPOKANE  HYDROCODONE
#
#    TRANSACTION_ID                          Product_Name     MME
# ...

# %%
# Check washington data to make sure no missing values 
washington_data_df.count()
# Out:
# REPORTER_DEA_NO     5423267
# REPORTER_BUS_ACT    5423267
# REPORTER_NAME       5423267
# BUYER_DEA_NO        5423267
# BUYER_BUS_ACT       5423267
# BUYER_NAME          5423267
# BUYER_COUNTY        5423267
# DRUG_NAME           5423267
# TRANSACTION_ID      5423267
# Product_Name        5423267
# MME                 5423267
# dtype: int64

# %%
# Reduce Washington data for same reason, too big for pgadmin
WA_county_df = washington_data_df.loc[washington_data_df["BUYER_COUNTY"]=="CLARK"]
WA_county_df
# Out:
#         REPORTER_DEA_NO REPORTER_BUS_ACT  \
# 22            PK0132821      DISTRIBUTOR
# 23            PK0132821      DISTRIBUTOR
# 24            PK0132821      DISTRIBUTOR
# 46            PK0132821      DISTRIBUTOR
# 47            PK0132821      DISTRIBUTOR
# ...                 ...              ...
# 5423169       RD0269109     MANUFACTURER
# 5423170       RD0269109     MANUFACTURER
# 5423179       RD0269109     MANUFACTURER
# 5423198       RD0271130      DISTRIBUTOR
# 5423228       RD0277409      DISTRIBUTOR
#
#                                 REPORTER_NAME BUYER_DEA_NO    BUYER_BUS_ACT  \
# 22                KAISER FNDTN HEALTH PLAN NW    AK7768952  RETAIL PHARMACY
# 23                KAISER FNDTN HEALTH PLAN NW    AK7768952  RETAIL PHARMACY
# 24                KAISER FNDTN HEALTH PLAN NW    AK7768952  RETAIL PHARMACY
# 46                KAISER FNDTN HEALTH PLAN NW    BK1783263  RETAIL PHARMACY
# 47                KAISER FNDTN HEALTH PLAN NW    BK1783263  RETAIL PHARMACY
# ...

# %%
# Export dataframes to smaller csv files
WA_county_df.to_csv(r'CSV_files/WA_county_data.csv', index=False)

# %%
OR_county_df.to_csv(r'CSV_files/OR_county_data.csv', index=False)
